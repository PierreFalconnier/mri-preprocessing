# %%
import pandas as pd

# -----------------------------
# Load data
# -----------------------------
# file_path = "/home/falconnier/Documents/PPMI_study_data_starting_point/PPMI_Curated_Data_Cut_Public_20251112.xlsx"
file_path = "/home/falconnier/Documents/mri-preprocessing/csv_dir/PPMI_Curated_Data_Cut_Public_20251112.xlsx"
df_curated = pd.read_excel(file_path)

file_path = "/home/falconnier/Documents/mri-preprocessing/csv_dir/PPMI/Xing_Core_Lab_-_MRI_acquisition_metadata_18Feb2026.csv"
df_mri = pd.read_csv(file_path)

# %%
print(df_mri.columns.tolist())
print(df_mri.head())
# Out:
# ['PROTOCOL', 'PATNO', 'EVENT_ID', 'MRI_SCAN_DATE', 'MRI_SEQ_DTI', 'MRI_SEQ_RS', 'MRI_SEQ_T1_WEIGHTED', 'MRI_SEQ_T2_WEIGHTED', 'MRI_SEQ_NM_MT', 'MRI_IMAGE_ACCEPTABLE']
#   PROTOCOL  PATNO EVENT_ID MRI_SCAN_DATE MRI_SEQ_DTI MRI_SEQ_RS  \
# 0      001   3000      NaN       02/2011          No        NaN
# 1      001   3001      NaN       03/2011          No        NaN
# 2      001   3002      NaN       03/2011          No        NaN
# 3      001   3003      NaN       04/2011          No        NaN
# 4      001   3004      NaN       04/2011          No        NaN
#
#   MRI_SEQ_T1_WEIGHTED MRI_SEQ_T2_WEIGHTED MRI_SEQ_NM_MT MRI_IMAGE_ACCEPTABLE
# 0                 NaN                 NaN           NaN                  NaN
# 1                 NaN                 NaN           NaN                  NaN
# 2                 NaN                 NaN           NaN                  NaN
# 3                 NaN                 NaN           NaN                  NaN
# 4                 NaN                 NaN           NaN                  NaN

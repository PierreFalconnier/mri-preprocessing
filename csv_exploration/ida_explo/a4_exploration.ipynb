# %% [markdown]
# The PPMI repository contains the full set of clinical, imaging and biological data collected as part of this ongoing study along with processed images and biospecimen analysis results. The repository is updated regularly as longitudinal follow-up of study subjects continues and data generated from a variety of CSF, DNA, serum, plasma and RNA analysis techniques are completed.

# %% [markdown]
# # Setup and Libraries

# %%
# Cell 0: get current notebook path, its parent, and project root (parent of parent)
import os
from pathlib import Path

# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: improve plots appearance
sns.set(style="whitegrid")

ROOT_DIR = Path(os.getcwd()).resolve().parents[1]

# %% [markdown]
# # Load the CSV and parse Imaging Protocol

# %%
CSV_DIR = ROOT_DIR / "csv_dir"
original_df = pd.read_csv(CSV_DIR / "A4_idaSearch_MRI_PET.csv")


# little adjustments
original_df["Subject ID"] = original_df["Subject ID"].astype("category")
original_df["Image ID"] = original_df["Image ID"].astype("category")
original_df["Weight"] = original_df["Weight"].replace(0, np.nan)
original_df["Age"] = original_df["Age"].replace(0, np.nan)
original_df["Study Date"] = pd.to_datetime(original_df["Study Date"], errors="coerce")

print(original_df.columns)
print(len(original_df))

fields = [
    "Acquisition Plane",
    "Slice Thickness",
    "Matrix Z",
    "Acquisition Type",
    "Manufacturer",
    "Mfg Model",
    "Field Strength",
    "Weighting",
]

numeric_fields = ["Slice Thickness", "Matrix Z", "Field Strength"]


def parse_imaging_protocol(text):
    if pd.isna(text):
        return {}

    items = text.split(";")
    parsed = {}

    for item in items:
        if "=" in item:
            key, value = item.split("=", 1)
            parsed[key.strip()] = value.strip()

    return parsed


# Parse the column into dictionaries
protocol_parsed = original_df["Imaging Protocol"].apply(parse_imaging_protocol)

# Create new columns
for field in fields:
    original_df[field] = protocol_parsed.apply(lambda x: x.get(field, np.nan))


for field in numeric_fields:
    original_df[field] = pd.to_numeric(original_df[field], errors="coerce")

print(original_df.columns)
# Out:
# Index(['Subject ID', 'Project', 'Sex', 'Weight', 'Research Group', 'Visit',
#        'Study Date', 'Archive Date', 'Age', 'Modality', 'Description', 'Type',
#        'Imaging Protocol', 'Image ID', 'Structure', 'Laterality', 'Image Type',
#        'Registration', 'Tissue'],
#       dtype='object')
# 12609
# Index(['Subject ID', 'Project', 'Sex', 'Weight', 'Research Group', 'Visit',
#        'Study Date', 'Archive Date', 'Age', 'Modality', 'Description', 'Type',
#        'Imaging Protocol', 'Image ID', 'Structure', 'Laterality', 'Image Type',
#        'Registration', 'Tissue', 'Acquisition Plane', 'Slice Thickness',
#        'Matrix Z', 'Acquisition Type', 'Manufacturer', 'Mfg Model',
#        'Field Strength', 'Weighting'],
#       dtype='object')

# %%
original_df["Description"].unique()
# Out:
# array(['Florbetapir <- a4_50_70_fbp_dyn', 'Florbetapir <- PET Scan',
#        'T2_SE; DeFaced <- Axial T2 TSE with Fat Sat',
#        'T2_star <- AX_T2_STAR',
#        'T1; GradWarp; DeFaced <- Sagittal 3D Accelerated MPRAGE',
#        'FLAIR; DeFaced <- AX_T2_FLAIR',
#        'FLAIR; DeFaced <- Axial T2-FLAIR',
#        'T1; DeFaced <- Sagittal 3D Accelerated MPRAGE',
#        'T2_star <- AXIAL_T2_STAR', 'Florbetapir <- MNI lorbetapir Brain',
#        'T1; DeFaced <- Accelerated Sag IR-FSPGR',
#        'T2_star <- Axial T2 Star',
#        'T2_SE; DeFaced <- Axial T2 FSE with Fat Sat',
#        'FLAIR; DeFaced <- Axial FLAIR', 'Florbetapir <- FRAME 1',
#        'Florbetapir <- None Provided',
#        'T2_star <- Axial T2-Star MAY OBLIQUE',
#        'FLAIR; DeFaced <- Axial T2-FLAIR MAY OBLIQUE',
#        'T2_SE; DeFaced <- Axial T2-TSE NO OBLIQUE',
#        'Florbetapir <- Brain LM', 'Florbetapir <- 4X5_AC',
#        'Florbetapir <- LZAZ- (AC)', 'T2_star <- AX_T2_STAR (NO ANGLE)',
#        'FLAIR; DeFaced <- AX_T2_FLAIR (NO ANGLE)',
#        'T2_SE; DeFaced <- Axial T2 TSE with Fat Sat (NO ANGLE)',
#        'Florbetapir <- Dyn Brain 3D MAC',
#        'Florbetapir <- [DY_CTAC] Brain AV-45', 'Florbetapir <- MNI BRAIN',
#        'Flortaucipir <- PET Scan', 'Florbetapir <- LZAZ-',
#        'Florbetapir <- ANONYMIZED',
#        'Florbetapir <- [DY_CTAC_-db1] Dynamic Brain', 'Florbetapir <- IN',
#        'T2_star <- Axial T2-Star',
#        'T2_SE; DeFaced <- Axial T2-TSE with Fat Sat',
#        'Florbetapir <- NIH-AC)',
#        'T1; GradWarp; DeFaced <- Sagittal 3D Accelerated MPRAGE rpt',
#        'T2_SE; DeFaced <- Axial T2 TSE with Fat Sat rpt',
#        'Florbetapir <- Research AC', 'Florbetapir <- PET Brain AC',
#        'Flortaucipir <- PET Brain AC',
#        'Florbetapir <- 4 X 5 MIN AC BRAIN',
#        'Flortaucipir <- 6 X 5 MIN AC TAU BRAIN',
#        'Florbetapir <- ADC-040-',
#        'FLAIR; DeFaced <- Axial T2-FLAIR REPEAT',
#        'Flortaucipir <- _75_105_dyn',
#        'T2_star <- AX_T2_STAR (NO ANGLE)REPEAT',
#        'Florbetapir <- 3D_BRAIN_4X5', 'Florbetapir <- LZAZ AC 3D',
#        'Florbetapir <- BRAIN AC',
#        'Florbetapir <- MNI LZAX LILLY AD  3D BRAIN',
#        'T2_star <- AX_T2_STAR/GRE',
#        'Flortaucipir <- MNI LZAZ-TAU 3D BRAIN',
#        'Florbetapir <- p449s0_dyn_ctac_suv.img: LOR-RAMLA',
#        'Florbetapir <- PET WB', 'FLAIR; DeFaced <- AXIAL T2W-FLAIR',
#        'DWI <- AXIAL DWI', 'T2_SE; DeFaced <- AXIAL T2-TSE WITH FAT SAT',
#        'T1; DeFaced <- SAG ACCELERATED MPRAGE',
#        'T2_star <- AXIAL T2-STAR', 'Florbetapir <- PETAC TAPIR',
#        'Florbetapir <- PET Brain 128', 'DWI <- Axial DWI',
#        'T1; GradWarp; DeFaced <- Accelerated SAG IR-FSPGR',
#        'T2_SE; DeFaced <- Axial T2-FSE with FAT SAT',
#        'Florbetapir <- [DY_CTAC_dyn4fr5m_S] Dynamic Brain',
#        'Florbetapir <- H8M-MC-LZAZ/ADC-040-',
#        'Florbetapir <- [BR-DY_CTAC] AV45 Brain Dynamic',
#        'Florbetapir <- RECON', 'Florbetapir <- PETAC FLORBETAPIR',
#        'Florbetapir <- 3D PET BRAIN',
#        'Florbetapir <- TR:BRAIN 3D:AMYVID:IR CTAC',
#        'Florbetapir <- 4X5 AC', 'Florbetapir <- 4X5_AC Images',
#        'Florbetapir <- IN_AV45_50_70_DYN',
#        'Flortaucipir <- a4_75_115_av1451_dyn',
#        'T2_star <- AX_T2_STAR (NO ANGLE) REPEAT',
#        'FLAIR; DeFaced <- AX_T2_FLAIR (NO ANGLE) REPEAT',
#        'Florbetapir <- MNI_3D_BRAIN',
#        'Florbetapir <- PETAC w/FLORBETAPIR',
#        'Florbetapir <- PET Brain 4x5min dyn 50-70min',
#        'Florbetapir <- MNI_FLORBETAPIR_PET RECON',
#        'Florbetapir <- [AC],,,2,,,', 'Flortaucipir <- -T',
#        'Flortaucipir <- LZAZ- (AC)',
#        'Florbetapir <- p563s0_Brain_ctac_suv.img: LOR-RAMLA',
#        'Florbetapir <- LZAZ )', 'T2_star <- Axial T2-Star/GRE',
#        'T1; DeFaced <- SAG 3D ACCELERATED MPRAGE',
#        'T2_SE; DeFaced <- Axial T2 FSE-TSE with Fat Sat',
#        'Florbetapir <- PETAC  FLORBETAPIR', 'Florbetapir <- PET Brain',
#        'T1; GradWarp; DeFaced <- Sagittal 3D Accelerated T1',
#        'FLAIR; DeFaced <- Ax T2 Flair',
#        'Florbetapir <- PET Brain Hi Rez 1', 'Florbetapir <- -1',
#        'Florbetapir <- H8A-MC-LZAZ- (AC)', 'Flortaucipir <- LZAZ--T (AC)',
#        'Florbetapir <- H8A_MC_LZAZ (AC)',
#        'T1; GradWarp; DeFaced <- Sagittal 3D Accelerated MPRAGE REPEAT',
#        'Flortaucipir <- LZAZ_ (AC)', 'T2_star <- AX_T2_STAR REPEAT',
#        'Florbetapir <- [BR-DY_CTAC_SD] UH ADNI PET/CT BRAIN',
#        'Florbetapir <- PET Brain 50-55 MIN',
#        'Florbetapir <- [BR-DY_CTAC_N] Brain Dynamic',
#        'Florbetapir <- PET AC 3D BRAIN', 'Florbetapir <- LZA- (AC)',
#        'Florbetapir <- [BR-DY_CTAC] UH  BRAIN',
#        'T2_star <- Axial_T2_STAR', 'FLAIR; DeFaced <- Axial_T2_FLAIR',
#        'Florbetapir <- [DY_CTAC_1] Dynamic Brain',
#        'Florbetapir <- PET Brain 4x5min_LZAZ(',
#        'Florbetapir <- MNI Recon (AC)',
#        'Flortaucipir <- H8A-MC-LZAZ TAU 3D BRAIN',
#        'Florbetapir <- 3DBRAIN_AMYLOID_4X',
#        'Florbetapir <- p476s0_dyn_ctac_suv.img: LOR-RAMLA',
#        'Florbetapir <- PET Brain Hi Rez 4',
#        'Florbetapir <- [DY_CTAC_4frx5min] Dynamic Brain',
#        'Florbetapir <- H8A-MC-LZAZ-91 (AC)', 'T2_star <- AX T2 STAR',
#        'Flortaucipir <- H8A-MC-LZAZ--T (AC)',
#        'Florbetapir <- 2PET Brain 50-55min',
#        'T2_SE; DeFaced <- Ax T2-FSE- FAT SAT', 'Florbetapir <- (AC)',
#        'Florbetapir <- H8A_MC_LZAZ_ (AC)',
#        'Florbetapir <- [BR-DY_CTAC_DYN] AV45 Brain Dynamic',
#        'Florbetapir <- LZAZ-83 (AC)', 'Florbetapir <- MNI_3DBRAIN_C)',
#        'Flortaucipir <- PET Brain', 'Florbetapir <- PET Brain Hi Rez #1',
#        'Flortaucipir <- TAU-LZAZ AV-1451 Recon (AC)',
#        'Florbetapir <- Dyn_3D_Brain_H8A_MC_LZAZ_',
#        'Florbetapir <- PET BRAIN HI REZ 1', 'T1; DeFaced <- MPRAGE',
#        'Florbetapir <- PET AC tapir', 'Florbetapir <- LZAZ- (AC).',
#        'Florbetapir <- NIH-AV45 (AC)',
#        'FLAIR; DeFaced <- Axial T2-FLAIR_rpt',
#        'Florbetapir <- MNI LZAZ BRAIN', 'DWI <- Axial DWI_TRACEW',
#        'T1; DeFaced <- MPRAGE GRAPPA2',
#        'fMRI_rest <- Axial fcMRI (EYES OPEN)',
#        'Florbetapir <- [BR-DY_CTAC_1] AV45 Brain Dynamic',
#        'Florbetapir <- p575s0_brain_ctac_suv.img: LOR-RAMLA',
#        'FLAIR; DeFaced <- AX_T2_FLAIR (NO ANGLE ON SAG)',
#        'T2_star <- AX_T2_STAR (NO ANGLE ON SAG)',
#        'T1; GradWarp; DeFaced <- SAG 3D Accelerated MPRAGE',
#        'T2_SE; DeFaced <- AX T2 TSE with Fat Sat (NO ANGLE ON SAG)',
#        'Flortaucipir <- MNI V1451 Brain',
#        'FLAIR; DeFaced <- Axial T2-FLAIR REPEATED', 'Flortaucipir <- T',
#        'Flortaucipir <- LZAZ  AV1451,SUV,3D gauss(mm): 5.00,FORE,OSEM(16,4)',
#        'Florbetapir <- MNI LZAZ 3D BRAIN 4X5',
#        'Florbetapir <- [BR-DY_CTAC_MEO] UH  BRAIN',
#        'Florbetapir <- MNI_H8A-MC-LZAZ_4x5 (AC)',
#        'Florbetapir <- PETAC Florbetapir', 'T2_star <- AX_T2_STAR GRE',
#        'Florbetapir <- LZAZ-70 (AC)',
#        'Florbetapir <- [BR-DY_CTAC_DYN] UH  BRAIN',
#        'Florbetapir <- LZAZ_ (AC)',
#        'Florbetapir <- PET BRAIN 20 MIN LIST-MODE',
#        'Florbetapir <- -E-LM', 'Florbetapir <- FRAME 1 (AC)',
#        "Florbetapir <- PET Florbetapir 4x5'",
#        'T2_star <- AXIAL_T2_STAR REPEAT', 'Florbetapir <- LZAZ-8 (AC)',
#        'T1; DeFaced <- Sagittal 3D Accelerated MPRAGE     straight  do not oblique',
#        'T2_star <- AX_T2_STAR    straight axial do not oblique',
#        'T2_SE; DeFaced <- Axial T2 TSE with Fat Sat    straight axial do not oblique',
#        'FLAIR; DeFaced <- AX_T2_FLAIR     straight axial do not oblique',
#        'Florbetapir <- PET BRAIN 30 MIN LIST-MODE',
#        'FLAIR; DeFaced <- Axial T2-FLAIR- REPEAT',
#        'T2_SE; DeFaced <- Axial T2 TSE with Fat Sat- REPEAT',
#        'Florbetapir <- 4x5_AC',
#        'Florbetapir <- [BR-DY_CTAC_dyn] UH  BRAIN',
#        'Florbetapir <- BRAIN tapir (AC)',
#        'Florbetapir <- p358s0_dyn_ctac.img: LOR-RAMLA',
#        'T1; DeFaced <- SAG3DMPRAGE', 'T2_star <- AX T2* STAR',
#        'FLAIR; DeFaced <- AX T2 FLAIR', 'Florbetapir <- -E',
#        'Flortaucipir <- MNI Brain AC 3D',
#        'FLAIR; DeFaced <- Axial T2-FLAIR repeat',
#        'Florbetapir <- [BR-DY_CTAC_MC] UH  BRAIN',
#        'T2_SE; DeFaced <- Axial T2 TSE with Fat Sat REPEAT',
#        'Florbetapir <- p473s0_dyn_brain_ctac_suv.img: LOR-RAMLA',
#        'T2_star <- XEAX T2* STAR', 'T2_SE; DeFaced <- XEAXIALT2TSEFS',
#        'T1; DeFaced <- XESAG3DMPRAGE', 'FLAIR; DeFaced <- XEAX T2 FLAIR',
#        'Flortaucipir <- p473s1_Brain_CTAC_SUV.img: LOR-RAMLA',
#        'Florbetapir <- p404s0_dyn_ctac.img: LOR-RAMLA',
#        'T2_SE; DeFaced <- AXIALT2TSEFS',
#        'Florbetapir <- [BR-DY_CTAC_SD] UH  BRAIN',
#        'T2_SE; DeFaced <- Axial T2 TSE',
#        'Florbetapir <- LZAZ AV45,SUV,3D gauss(mm): 5.00,FORE,OSEM(16,4)',
#        'Flortaucipir <- -T-LIST-MODE',
#        'Florbetapir <- p359s0_dyn_ctac.img: LOR-RAMLA',
#        'Flortaucipir <- [BR-DY_CTAC] Brain Dynamic',
#        'T2_star <- AX_T2_STAR REPEAT 2', 'Florbetapir <- NAV4-04 AC',
#        'T2_star <- AX_T2_STAR repeat', 'Florbetapir <- LZAZ-69 (AC)',
#        'Florbetapir <- p414s0_dyn.brain.ctac.img: LOR-RAMLA',
#        'FLAIR; DeFaced <- Axial T2-FLAIR_REPEAT',
#        'Florbetapir <- [BR-DY_CTAC_JA] UH  BRAIN',
#        'Florbetapir <- PETAC W/FLORBETAPIR', 'Florbetapir <- -LM',
#        'T2_star <- AX_T2_STAR (NO ANGLE) repeat',
#        'T1; GradWarp; DeFaced <- Head_Sagittal 3D Accelerated MPRAGE_ND',
#        'T2_star <- Head_AXIAL_T2_ STAR',
#        'T2_SE; DeFaced <- Head_Axial T2 TSE with Fat Sat',
#        'FLAIR; DeFaced <- Head_Axial T2-FLAIR',
#        'T1; DeFaced <- Head_Sagittal 3D Accelerated MPRAGE',
#        'Florbetapir <- PET WB-1',
#        'Florbetapir <- 3D_BRAIN_AC ITER 4_14 GAUSS 5.0',
#        'Flortaucipir <- MNI con (AC)',
#        'Florbetapir <- p229s0_dyn_ctacsuv.img: LOR-RAMLA',
#        'Flortaucipir <- MNI V1451 Brain Dyn',
#        'Florbetapir <- LZAZ--R (AC)', 'Florbetapir <- AD040-',
#        'Florbetapir <- Dynamic 4 x 5 min 4 x 12',
#        'Florbetapir <- 4x5_AC Images', 'fMRI_rest <- None Provided',
#        'DWI <- None Provided', 'T2_SE; DeFaced <- None Provided',
#        'FLAIR; DeFaced <- None Provided', 'T2_star <- None Provided',
#        'T1; GradWarp; DeFaced <- None Provided',
#        'Florbetapir <- [BR-DY_CTAC_H A4 PET/CT BRAIN',
#        'Florbetapir <- p420s0_dyn_ctac.img: LOR-RAMLA',
#        'Florbetapir <- p392s0_brain_ctac.img: LOR-RAMLA',
#        'T2_SE; DeFaced <- Axial T2 TSE with Fat Sat     straight axial do not oblique',
#        'T1; DeFaced <- Sagittal 3D Accelerated MPRAGE     straight do not oblique',
#        'Florbetapir <- LZAZ-H8A-MC- (AC)',
#        'Flortaucipir <- FRAME 1 B (AC)', 'Florbetapir <- LZAZ-56 (AC)',
#        'Flortaucipir <- _93_123_dyn',
#        'Flortaucipir <- PET Brain 6x5min dyn 75-105min',
#        'Florbetapir <- LZAZ-37 (AC)',
#        'Florbetapir <- p403s0_dyn_ctac.img: LOR-RAMLA',
#        'Florbetapir <- 9-1',
#        'Flortaucipir <- PETAC AV-1451 TAU ADDENDUM 6X5',
#        'Florbetapir <- [BR-DY_CTAC] AV45 Brain Dynamic (19)',
#        'Flortaucipir <- LZAZ AV_1451_BRAIN (AC)',
#        'T2_star <- AXIAL_T2_STAR RPT', 'Flortaucipir <- [DY_CTAC] Brain',
#        'Flortaucipir <- None Provided',
#        'FLAIR; DeFaced <- AX_T2_FLAIR repeat',
#        'Florbetapir <- LZAZ-96 (AC)',
#        'FLAIR; DeFaced <- AX_T2_FLAIR REPEAT',
#        'Flortaucipir <- AVID_AV1451_75_105_dyn',
#        'Florbetapir <- p390s0_brain_ctac.img: LOR-RAMLA',
#        'Florbetapir <- p330s0_dyn_brainctac.img: LOR-RAMLA',
#        'Florbetapir <- LZAZ-60 (AC)', 'Flortaucipir <- Dyn Brain 3D MAC',
#        'Florbetapir <- p433s0_dyn_brain_ctac_suv.img: LOR-RAMLA',
#        'Florbetapir <- p348s0_dyn_ctac.img: LOR-RAMLA',
#        'Florbetapir <- p331s0_dyn_brainctac.img: LOR-RAMLA',
#        'Florbetapir <- p413s0_dyn_brain_ctac_suv.img: LOR-RAMLA',
#        'Flortaucipir <- TAU_H8A_MC_LZAX_3D_BRAIN_6X5',
#        'Florbetapir <- MNI lorbetapir Brain ACQ',
#        'Florbetapir <- [BR-DY_CTAC_meo2] UH  BRAIN',
#        'T1; GradWarp; DeFaced <- COR MPRAGE',
#        'fMRI_rest <- Axial fcMRI (Eyes Open)',
#        'T1; GradWarp; DeFaced <- Accelerated Sag IR-FSPGR',
#        'Florbetapir <- MNI 3DBRAIN 4A 4X5',
#        'FLAIR; DeFaced <- Axial T2-FLAIR rpt',
#        'Florbetapir <- PET Brain 1', 'Florbetapir <- LZAZ-599 (AC)',
#        'Florbetapir <- Brain_M (AC)',
#        'Florbetapir <- [BR-DY_CTAC_dyn] UH ADNI PET/CT BRAIN',
#        'Florbetapir <- MNI BRAIN AC', 'Flortaucipir <- MNI BRAIN AC',
#        'Florbetapir <- LAZ- (AC)',
#        'Flortaucipir <- PET_Brain_AC_Gaussian5.0mm_4Iterations_12Subsets',
#        'Florbetapir <- p419s0_dyn_ctac.img: LOR-RAMLA',
#        'T2_SE; DeFaced <- AX T2 SPACE', 'Florbetapir <- LZAZ AC)',
#        'Flortaucipir <- LZAZ_AV1451_75_105_dyn',
#        'Florbetapir <- LZAZ-78 (AC)', 'Florbetapir <- LZAZ-27 (AC)',
#        'FLAIR; DeFaced <- t2_Flair_axial_T',
#        'Florbetapir <- p412s0_dyn.brain.ctac.suv.img: LOR-RAMLA',
#        'T2_star <- AXIAL_T2_ STAR', 'Florbetapir <- _E_1_LIST-MODE',
#        'Florbetapir <- [BR-DY_CTAC_GP] UH  BRAIN',
#        'Florbetapir <- LZAX AV45 BRAIN (AC)',
#        'Flortaucipir <- H8A-MC-LZAZ-AV-1451-TAU',
#        'Florbetapir <- LZAZ-34 (AC)',
#        'Flortaucipir <- [BR-DY_CTAC] AV1451 Brain Dynamic',
#        'Florbetapir <- p434s0_dyn_brain_ctac_suv.img: LOR-RAMLA',
#        'FLAIR; DeFaced <- Axial T2-FLAIR RPT',
#        'Flortaucipir <- MNI con (CCIR-0702) (AC)', 'Florbetapir <- LZAZ',
#        'fMRI_rest <- AX fcMRI (EYES OPEN, NO ANGLE ON SAG)',
#        'DWI <- AX DWI  (NO ANGLE ON SAG)_TRACEW',
#        'Florbetapir <- LZAZ-53 (AC)',
#        'Florbetapir <- p589s0_BRAIN_CTAC_SUV.img: LOR-RAMLA',
#        'Florbetapir <- LZAZ-80 (AC)', 'T2_star <- XEAX T2* GRE',
#        'T2_SE; DeFaced <- XEAX T2 TSE', 'T1; DeFaced <- None Provided',
#        'Florbetapir <- 3D F18 ACQUISI. 4i/16s',
#        'T2_star <- AXIAL_T2_STAR XXXX',
#        'Flortaucipir <- LZAZ AV_145 1_BRAIN (AC)',
#        'Florbetapir <- -E-LM_1',
#        'Florbetapir <- [BR-DY_CTAC_DYNAMIC] UH  BRAIN',
#        'Florbetapir <- [BR-DY_CTAC_SC] UH  BRAIN',
#        'Florbetapir <- LZAZ-21 (AC)',
#        'Florbetapir <- H8A-MC-LZAZ-53 (AC)',
#        'Flortaucipir <- LZAZ--T2 (AC)', 'Flortaucipir <- FRAME 1',
#        'Florbetapir <- PET Brain Hi Rez (AC) 1',
#        'T2_star <- Axial T2 Star #2',
#        'Florbetapir <- [BR-DY_CTAC_2] UH  BRAIN',
#        'Florbetapir <- p314s0_dyn_brain_ctac.img: LOR-RAMLA',
#        'Florbetapir <- LZAZ-00 (AC)',
#        'Florbetapir <- [BR-DY_CTAC_ PET/CT BRAIN',
#        'T1; DeFaced <- Accelerated Sagittal MPRAGE',
#        'T2_star <- AXIAL_T2_STAR rpt',
#        'T2_star <- AX_T2_STAR (NO ANGLE ON SAG) REPEAT',
#        'Flortaucipir <- PET', 'FLAIR; DeFaced <- AX FLAIR',
#        'T2_star <- gre', 'T1; GradWarp; DeFaced <- MPRAGE',
#        'T2_star <- AX_T2_STAR (NO ANGLE)  REPEAT',
#        'Florbetapir <- PET Brain FRAME 1',
#        'Florbetapir <- p316s0_dyn_brain_suv.img: LOR-RAMLA',
#        'Flortaucipir <- LZAZ-05-T (AC)',
#        'T2_SE; DeFaced <- Axial T2-TSE with Fat Sat_RPT',
#        'FLAIR; DeFaced <- Axial T2-FLAIR_RPT',
#        'FLAIR; DeFaced <- Axial T2-FLAIR_RPT2',
#        'Flortaucipir <- [DY_CTAC_1] Dynamic Brain',
#        'Flortaucipir <- 6X5_AC', 'Florbetapir <- LZAZ-43 (AC)',
#        'fMRI_rest <- Axial fcMRI (EYES OPEN, NO ANGLE)',
#        'DWI <- Axial DWI  (NO ANGLE)_TRACEW',
#        'Flortaucipir <- [BR-DY_CTAC] UH TAU PET/CT BRAIN',
#        'Florbetapir <- LZAZ AV45_BRAIN-R (AC)',
#        'Florbetapir <- *4X5_AC_PRR_AC Images',
#        'Flortaucipir <- PET Brain75-80',
#        'Flortaucipir <- PETAC AV-1451 Tau Imaging 6x5min',
#        'Florbetapir <- LZAZ_21 (AC)', 'Florbetapir <- LZAZ-26 (AC)',
#        'Florbetapir <- PET Brain - First 5min',
#        'FLAIR; DeFaced <- AX_T2_FLAIR (NO ANGLE ON SAG) REPEAT',
#        'Flortaucipir <- LZAZ-5-T (AC)', 'Florbetapir <- LZAZ 21 (AC)',
#        'Florbetapir <- PET Brain AC#1',
#        'T2_SE; DeFaced <- WIP Axial T2-TSE with Fat Sat CLEAR',
#        'FLAIR; DeFaced <- WIP Axial T2-FLAIR SENSE',
#        'T2_star <- WIP Axial T2-Star SENSE',
#        'T1; DeFaced <- WIP Sagittal 3D Accelerated MPRAGE SENSE',
#        'Flortaucipir <- MNI_3D_BRAIN',
#        'T1; DeFaced <- Sagittal 3D Accelerated MPRAGE -MOTION REPEAT',
#        'Flortaucipir <- PETAC Tau Imaging',
#        'Florbetapir <- [BR-DY_CTAC_dyn] AV45 Brain Dynamic',
#        'FLAIR; DeFaced <- Axial T2-FLAIR SENSE',
#        'T1; DeFaced <- Sagittal 3D Accelerated MPRAGE SENSE',
#        'T2_SE; DeFaced <- Axial T2-TSE with Fat Sat CLEAR',
#        'T2_star <- Axial T2-Star SENSE',
#        'T2_SE; DeFaced <- Axial T2 TSE with Fat Sat (NO ANGLE) REPEAT',
#        'Florbetapir <- [BR-DY_CTAC_XXX] Brain Dynamic',
#        'FLAIR; DeFaced <- T2 Ax FLAIR', 'T1; DeFaced <- 3D MPRAGE',
#        'T2_SE; DeFaced <- t2_tse_tra_fat sat',
#        'T2_star <- t2_fl2d_tra_5mm', 'Florbetapir <- PET Brain AV_45',
#        'T2_star <- AX_T2_STAR repeat 3', 'T2_star <- AX_T2_STAR repeat 2',
#        'T1; GradWarp; DeFaced <- Sagittal 3D Accelerated MPRAGE repeat',
#        'Florbetapir <- e+1 Dyn_3D_Brain_H8A_MC_LZAZ_',
#        'Florbetapir <- p338s0_dyn_brainctac.img: LOR-RAMLA',
#        'FLAIR; DeFaced <- Axial FLAIR #3',
#        'Florbetapir <- p234s0_dyn_ctacsuv.img: LOR-RAMLA',
#        'Florbetapir <- [BR-DY_CTAC_SD] Brain',
#        'Florbetapir <- H8A-MC-LZAZ-ADC-040-',
#        'Flortaucipir <- TAU_H8A_MC_LZAZ_2_3D_BRAIN_6X5',
#        'FLAIR; DeFaced <- Ax FLAIR BRAIN',
#        'T2_SE; DeFaced <- Ax T2 FSE w FAT SAT TE 80',
#        'T1; DeFaced <- FAT: SAG 3D FSPGR-IR', 'T2_star <- T2* GRE',
#        'T1; DeFaced <- SAG IR - FSPGR',
#        'T1; DeFaced <- WATER: SAG 3D FSPGR-IR',
#        'Florbetapir <- 3D_Brain_AC ITER 4_14 GAUSS 5.0',
#        'Florbetapir <- [BR-DY_CTAC_SD] UH',
#        'Florbetapir <- p567s1_Brain_ctac_suv.img: LOR-RAMLA',
#        'T2_SE; DeFaced <- Axial T2 TSE with Fat Sat (NO ANGLE) (REPEAT)',
#        'Florbetapir <- LZAZ-0 (AC)', 'Flortaucipir <- -E-T-LIST-MODE',
#        'Florbetapir <- [BR-DY_CTAC_2]',
#        'FLAIR; DeFaced <- repeat Axial T2-FLAIR',
#        'Florbetapir <- p360s0_dyn_ctac.img: LOR-RAMLA',
#        'Florbetapir <- LZAZ-31 (AC)',
#        'Florbetapir <- [DY_CTAC_dyn4fr5m_S] 10.10',
#        'Florbetapir <- p349s0_dyn_ctac.img: LOR-RAMLA',
#        'Florbetapir <- PET WB (AC)', 'Florbetapir <- LZAZ-62 (AC)',
#        'Florbetapir <- PET Brain#1',
#        'Florbetapir <- p350s0_dyn_ctac.img: LOR-RAMLA',
#        'Florbetapir <- p435s0_dyn_brain_ctac_suv.img: LOR-RAMLA',
#        'Flortaucipir <- -E-LM',
#        'Florbetapir <- p418s0_dyn_brain_ctac_suv.img: LOR-RAMLA',
#        'Florbetapir <- Amaranth Florbetapir (AC)',
#        'Florbetapir <- 4X5_AC_Images', 'Flortaucipir <- FRAME 1 (AC)',
#        'Florbetapir <- I5T-MC-AACD-LZAZ- (AC)',
#        'Florbetapir <- [BR-DY_CTAC] AV45 Brain Dynamic (18)',
#        'Florbetapir <- LZAZ-82 (AC)',
#        'Florbetapir <- [BR-DY_CTAC_-R] UH  BRAIN',
#        'Florbetapir <- PET Brain Hi Rez (AC) #1',
#        'Florbetapir <- LZAZ-(AC).',
#        'Flortaucipir <- PETAC 1 Tau Addendum',
#        'Flortaucipir <- _75_105_dyn_6x5min',
#        'Florbetapir <- p442s0_dyn_brain_ctac_suv.img: LOR-RAMLA',
#        'Florbetapir <- FLORBETAPIR',
#        'Florbetapir <- PET Brain Hi Rez (AC)#1',
#        'Florbetapir <- p425s0_dyn_brain_ctac_suv.img: LOR-RAMLA',
#        'Florbetapir <- LZAZ_42-1 (AC)', 'Florbetapir <- PET Brain50-55',
#        'Florbetapir <- PETAC Brain#1',
#        'Florbetapir <- MNI LILLY AD  3D BRAIN',
#        'Florbetapir <- p450s0_brain_dyn_ctac_suv.img: LOR-RAMLA',
#        'Florbetapir <- PET AC w/FLORBETAPIR',
#        'Florbetapir <- p424s1_BRAIN_CTAC_SUV.img: LOR-RAMLA',
#        'FLAIR; DeFaced <- Axial T2-FLAIR REPEAT DUE TO MOTION',
#        'Florbetapir <- _R',
#        'Florbetapir <- p426s0_DYN_BRAIN_CTAC_SUV.img: LOR-RAMLA',
#        'Flortaucipir <- LZAZ-T (AC)', 'Florbetapir <- PETAC',
#        'Florbetapir <- [DY_CTAC_2] Dynamic Brain',
#        'Flortaucipir <- [BR-DY_CTAC_SD] UH TAU PET/CT BRAIN',
#        'Flortaucipir <- RECON',
#        'Florbetapir <- p458s0_brain_dyn_ctac_suv.img: LOR-RAMLA',
#        'Florbetapir <- [BR-DY_CTAC_SD2] UH  BRAIN',
#        'Florbetapir <- p540s0_brain_CTAC_SUV.img: LOR-RAMLA',
#        'FLAIR; DeFaced <- RPT_Axial T2-FLAIR', 'Florbetapir <- 5-1',
#        'Florbetapir <- -E- LIST-MODE'], dtype=object)

# %% [markdown]
# # Filtered dataframe

# %% [markdown]
# ### Basic filter

# %%
# Apply filters

df = original_df[
    (original_df["Modality"] == "MRI")
    # & (original_df["Weighting"] == "T1")
    # & (original_df["Matrix Z"] > 100)
    # & (original_df["Slice Thickness"] < 1.4)
    # & (original_df["Acquisition Type"] == "3D")
    # & (original_df["Type"] == "Original")
].copy()

print(
    f"Filtered dataset size: {df.shape[0]} images from {df['Subject ID'].nunique()} subjects."
)
df["Description"].unique()
# Out:
# Filtered dataset size: 7676 images from 1793 subjects.
# array(['T2_SE; DeFaced <- Axial T2 TSE with Fat Sat',
#        'T2_star <- AX_T2_STAR',
#        'T1; GradWarp; DeFaced <- Sagittal 3D Accelerated MPRAGE',
#        'FLAIR; DeFaced <- AX_T2_FLAIR',
#        'FLAIR; DeFaced <- Axial T2-FLAIR',
#        'T1; DeFaced <- Sagittal 3D Accelerated MPRAGE',
#        'T2_star <- AXIAL_T2_STAR',
#        'T1; DeFaced <- Accelerated Sag IR-FSPGR',
#        'T2_star <- Axial T2 Star',
#        'T2_SE; DeFaced <- Axial T2 FSE with Fat Sat',
#        'FLAIR; DeFaced <- Axial FLAIR',
#        'T2_star <- Axial T2-Star MAY OBLIQUE',
#        'FLAIR; DeFaced <- Axial T2-FLAIR MAY OBLIQUE',
#        'T2_SE; DeFaced <- Axial T2-TSE NO OBLIQUE',
#        'T2_star <- AX_T2_STAR (NO ANGLE)',
#        'FLAIR; DeFaced <- AX_T2_FLAIR (NO ANGLE)',
#        'T2_SE; DeFaced <- Axial T2 TSE with Fat Sat (NO ANGLE)',
#        'T2_star <- Axial T2-Star',
#        'T2_SE; DeFaced <- Axial T2-TSE with Fat Sat',
#        'T1; GradWarp; DeFaced <- Sagittal 3D Accelerated MPRAGE rpt',
#        'T2_SE; DeFaced <- Axial T2 TSE with Fat Sat rpt',
#        'FLAIR; DeFaced <- Axial T2-FLAIR REPEAT',
#        'T2_star <- AX_T2_STAR (NO ANGLE)REPEAT',
#        'T2_star <- AX_T2_STAR/GRE', 'FLAIR; DeFaced <- AXIAL T2W-FLAIR',
#        'DWI <- AXIAL DWI', 'T2_SE; DeFaced <- AXIAL T2-TSE WITH FAT SAT',
#        'T1; DeFaced <- SAG ACCELERATED MPRAGE',
#        'T2_star <- AXIAL T2-STAR', 'DWI <- Axial DWI',
#        'T1; GradWarp; DeFaced <- Accelerated SAG IR-FSPGR',
#        'T2_SE; DeFaced <- Axial T2-FSE with FAT SAT',
#        'T2_star <- AX_T2_STAR (NO ANGLE) REPEAT',
#        'FLAIR; DeFaced <- AX_T2_FLAIR (NO ANGLE) REPEAT',
#        'T2_star <- Axial T2-Star/GRE',
#        'T1; DeFaced <- SAG 3D ACCELERATED MPRAGE',
#        'T2_SE; DeFaced <- Axial T2 FSE-TSE with Fat Sat',
#        'T1; GradWarp; DeFaced <- Sagittal 3D Accelerated T1',
#        'FLAIR; DeFaced <- Ax T2 Flair',
#        'T1; GradWarp; DeFaced <- Sagittal 3D Accelerated MPRAGE REPEAT',
#        'T2_star <- AX_T2_STAR REPEAT', 'T2_star <- Axial_T2_STAR',
#        'FLAIR; DeFaced <- Axial_T2_FLAIR', 'T2_star <- AX T2 STAR',
#        'T2_SE; DeFaced <- Ax T2-FSE- FAT SAT', 'T1; DeFaced <- MPRAGE',
#        'FLAIR; DeFaced <- Axial T2-FLAIR_rpt', 'DWI <- Axial DWI_TRACEW',
#        'T1; DeFaced <- MPRAGE GRAPPA2',
#        'fMRI_rest <- Axial fcMRI (EYES OPEN)',
#        'FLAIR; DeFaced <- AX_T2_FLAIR (NO ANGLE ON SAG)',
#        'T2_star <- AX_T2_STAR (NO ANGLE ON SAG)',
#        'T1; GradWarp; DeFaced <- SAG 3D Accelerated MPRAGE',
#        'T2_SE; DeFaced <- AX T2 TSE with Fat Sat (NO ANGLE ON SAG)',
#        'FLAIR; DeFaced <- Axial T2-FLAIR REPEATED',
#        'T2_star <- AX_T2_STAR GRE', 'T2_star <- AXIAL_T2_STAR REPEAT',
#        'T1; DeFaced <- Sagittal 3D Accelerated MPRAGE     straight  do not oblique',
#        'T2_star <- AX_T2_STAR    straight axial do not oblique',
#        'T2_SE; DeFaced <- Axial T2 TSE with Fat Sat    straight axial do not oblique',
#        'FLAIR; DeFaced <- AX_T2_FLAIR     straight axial do not oblique',
#        'FLAIR; DeFaced <- Axial T2-FLAIR- REPEAT',
#        'T2_SE; DeFaced <- Axial T2 TSE with Fat Sat- REPEAT',
#        'T1; DeFaced <- SAG3DMPRAGE', 'T2_star <- AX T2* STAR',
#        'FLAIR; DeFaced <- AX T2 FLAIR',
#        'FLAIR; DeFaced <- Axial T2-FLAIR repeat',
#        'T2_SE; DeFaced <- Axial T2 TSE with Fat Sat REPEAT',
#        'T2_star <- XEAX T2* STAR', 'T2_SE; DeFaced <- XEAXIALT2TSEFS',
#        'T1; DeFaced <- XESAG3DMPRAGE', 'FLAIR; DeFaced <- XEAX T2 FLAIR',
#        'T2_SE; DeFaced <- AXIALT2TSEFS', 'T2_SE; DeFaced <- Axial T2 TSE',
#        'T2_star <- AX_T2_STAR REPEAT 2', 'T2_star <- AX_T2_STAR repeat',
#        'FLAIR; DeFaced <- Axial T2-FLAIR_REPEAT',
#        'T2_star <- AX_T2_STAR (NO ANGLE) repeat',
#        'T1; GradWarp; DeFaced <- Head_Sagittal 3D Accelerated MPRAGE_ND',
#        'T2_star <- Head_AXIAL_T2_ STAR',
#        'T2_SE; DeFaced <- Head_Axial T2 TSE with Fat Sat',
#        'FLAIR; DeFaced <- Head_Axial T2-FLAIR',
#        'T1; DeFaced <- Head_Sagittal 3D Accelerated MPRAGE',
#        'fMRI_rest <- None Provided', 'DWI <- None Provided',
#        'T2_SE; DeFaced <- None Provided',
#        'FLAIR; DeFaced <- None Provided', 'T2_star <- None Provided',
#        'T1; GradWarp; DeFaced <- None Provided',
#        'T2_SE; DeFaced <- Axial T2 TSE with Fat Sat     straight axial do not oblique',
#        'T1; DeFaced <- Sagittal 3D Accelerated MPRAGE     straight do not oblique',
#        'T2_star <- AXIAL_T2_STAR RPT',
#        'FLAIR; DeFaced <- AX_T2_FLAIR repeat',
#        'FLAIR; DeFaced <- AX_T2_FLAIR REPEAT',
#        'T1; GradWarp; DeFaced <- COR MPRAGE',
#        'fMRI_rest <- Axial fcMRI (Eyes Open)',
#        'T1; GradWarp; DeFaced <- Accelerated Sag IR-FSPGR',
#        'FLAIR; DeFaced <- Axial T2-FLAIR rpt',
#        'T2_SE; DeFaced <- AX T2 SPACE',
#        'FLAIR; DeFaced <- t2_Flair_axial_T', 'T2_star <- AXIAL_T2_ STAR',
#        'FLAIR; DeFaced <- Axial T2-FLAIR RPT',
#        'fMRI_rest <- AX fcMRI (EYES OPEN, NO ANGLE ON SAG)',
#        'DWI <- AX DWI  (NO ANGLE ON SAG)_TRACEW',
#        'T2_star <- XEAX T2* GRE', 'T2_SE; DeFaced <- XEAX T2 TSE',
#        'T1; DeFaced <- None Provided', 'T2_star <- AXIAL_T2_STAR XXXX',
#        'T2_star <- Axial T2 Star #2',
#        'T1; DeFaced <- Accelerated Sagittal MPRAGE',
#        'T2_star <- AXIAL_T2_STAR rpt',
#        'T2_star <- AX_T2_STAR (NO ANGLE ON SAG) REPEAT',
#        'FLAIR; DeFaced <- AX FLAIR', 'T2_star <- gre',
#        'T1; GradWarp; DeFaced <- MPRAGE',
#        'T2_star <- AX_T2_STAR (NO ANGLE)  REPEAT',
#        'T2_SE; DeFaced <- Axial T2-TSE with Fat Sat_RPT',
#        'FLAIR; DeFaced <- Axial T2-FLAIR_RPT',
#        'FLAIR; DeFaced <- Axial T2-FLAIR_RPT2',
#        'fMRI_rest <- Axial fcMRI (EYES OPEN, NO ANGLE)',
#        'DWI <- Axial DWI  (NO ANGLE)_TRACEW',
#        'FLAIR; DeFaced <- AX_T2_FLAIR (NO ANGLE ON SAG) REPEAT',
#        'T2_SE; DeFaced <- WIP Axial T2-TSE with Fat Sat CLEAR',
#        'FLAIR; DeFaced <- WIP Axial T2-FLAIR SENSE',
#        'T2_star <- WIP Axial T2-Star SENSE',
#        'T1; DeFaced <- WIP Sagittal 3D Accelerated MPRAGE SENSE',
#        'T1; DeFaced <- Sagittal 3D Accelerated MPRAGE -MOTION REPEAT',
#        'FLAIR; DeFaced <- Axial T2-FLAIR SENSE',
#        'T1; DeFaced <- Sagittal 3D Accelerated MPRAGE SENSE',
#        'T2_SE; DeFaced <- Axial T2-TSE with Fat Sat CLEAR',
#        'T2_star <- Axial T2-Star SENSE',
#        'T2_SE; DeFaced <- Axial T2 TSE with Fat Sat (NO ANGLE) REPEAT',
#        'FLAIR; DeFaced <- T2 Ax FLAIR', 'T1; DeFaced <- 3D MPRAGE',
#        'T2_SE; DeFaced <- t2_tse_tra_fat sat',
#        'T2_star <- t2_fl2d_tra_5mm', 'T2_star <- AX_T2_STAR repeat 3',
#        'T2_star <- AX_T2_STAR repeat 2',
#        'T1; GradWarp; DeFaced <- Sagittal 3D Accelerated MPRAGE repeat',
#        'FLAIR; DeFaced <- Axial FLAIR #3',
#        'FLAIR; DeFaced <- Ax FLAIR BRAIN',
#        'T2_SE; DeFaced <- Ax T2 FSE w FAT SAT TE 80',
#        'T1; DeFaced <- FAT: SAG 3D FSPGR-IR', 'T2_star <- T2* GRE',
#        'T1; DeFaced <- SAG IR - FSPGR',
#        'T1; DeFaced <- WATER: SAG 3D FSPGR-IR',
#        'T2_SE; DeFaced <- Axial T2 TSE with Fat Sat (NO ANGLE) (REPEAT)',
#        'FLAIR; DeFaced <- repeat Axial T2-FLAIR',
#        'FLAIR; DeFaced <- Axial T2-FLAIR REPEAT DUE TO MOTION',
#        'FLAIR; DeFaced <- RPT_Axial T2-FLAIR'], dtype=object)

# %% [markdown]
# ### more advanced

# %%
# # Apply filters
# weighting_filter = (original_df["Weighting"] == "T1") | (
#     (original_df["Weighting"] == "PD")
#     & original_df["Description"].str.contains("T1", case=False, na=False)
# )

# df = original_df[
#     (original_df["Modality"] == "MRI")
#     & weighting_filter
#     & (original_df["Matrix Z"] > 100)
#     & (original_df["Slice Thickness"] < 1.4)
#     & (original_df["Acquisition Type"] == "3D")
#     # & (original_df["Type"] == "Original")
# ].copy()

# print(
#     f"Filtered dataset size: {df.shape[0]} images from {df['Subject ID'].nunique()} subjects."
# )

# %% [markdown]
# ### No filter

# %%
# df = original_df

# %%
df.head(2)
# Out:
#   Subject ID Project Sex  Weight Research Group                 Visit  \
# 3  B10081264      A4   F    72.0       amyloidE  SCV4 (Screening MRI)
# 4  B10081264      A4   F    72.0       amyloidE  SCV4 (Screening MRI)
#
#   Study Date Archive Date   Age Modality  ... Registration Tissue  \
# 3 2016-01-01   11/12/2020  67.9      MRI  ...       native    All
# 4 2016-01-01   11/16/2020  67.9      MRI  ...       native    All
#
#    Acquisition Plane Slice Thickness Matrix Z Acquisition Type Manufacturer  \
# 3                NaN             NaN      NaN              NaN          NaN
# 4                NaN             NaN      NaN              NaN          NaN
#
#   Mfg Model Field Strength  Weighting
# 3       NaN            NaN        NaN
# 4       NaN            NaN        NaN
#
# [2 rows x 27 columns]

# %% [markdown]
# # Basic descriptions

# %%
# -------------------------------
# Column Names
# -------------------------------
print("=== Columns in the Dataset ===")
display(pd.DataFrame(df.columns, columns=["Column Names"]))

# -------------------------------
# Summary of Numeric Features
# -------------------------------
print("\n=== Numeric Features Summary ===")
display(df.describe().round(2))  # round to 2 decimals

# -------------------------------
# Summary of Categorical Features
# -------------------------------
print("\n=== Categorical Features Summary ===")
display(df.describe(include=["object", "category"]))

# -------------------------------
# Missing Values
# -------------------------------
missing_count = df.isnull().sum()
missing_percent = (missing_count / len(df) * 100).round(2)
missing_df = pd.DataFrame(
    {"Missing Count": missing_count, "Missing %": missing_percent}
).sort_values(by="Missing Count", ascending=False)

print("\n=== Missing Values by Column ===")
display(missing_df)

# Find columns with at least one missing value
cols_with_missing = df.columns[df.isnull().any()]
print(f"Columns with missing values ({len(cols_with_missing)}):\n")

# for col in cols_with_missing:
#     print(f"--- {col} ---")
#     # Show up to 5 rows where this column is missing
#     display(df[df[col].isnull()].head(3))
# Out:
# === Columns in the Dataset ===
#          Column Names
# 0          Subject ID
# 1             Project
# 2                 Sex
# 3              Weight
# 4      Research Group
# 5               Visit
# 6          Study Date
# 7        Archive Date
# 8                 Age
# 9            Modality
# 10        Description
# 11               Type
# 12   Imaging Protocol
# 13           Image ID
# 14          Structure
# 15         Laterality
# 16         Image Type
# 17       Registration
# 18             Tissue
# 19  Acquisition Plane
# 20    Slice Thickness
# 21           Matrix Z
# 22   Acquisition Type
# 23       Manufacturer
# 24          Mfg Model
# 25     Field Strength
# 26          Weighting
# === Numeric Features Summary ===
#         Weight                     Study Date      Age  Imaging Protocol  \
# count  7368.00                           7676  7175.00               0.0
# mean     76.98  2015-11-23 23:43:06.972381696    71.90               NaN
# min      22.70            2014-01-01 00:00:00    16.00               NaN
# 25%      65.30            2015-01-01 00:00:00    68.00               NaN
# 50%      75.70            2016-01-01 00:00:00    71.00               NaN
# 75%      86.20            2016-01-01 00:00:00    75.00               NaN
# max     142.90            2017-01-01 00:00:00   116.00               NaN
# std      16.21                            NaN     5.54               NaN
#
#        Acquisition Plane  Slice Thickness  Matrix Z  Acquisition Type  \
# count                0.0              0.0       0.0               0.0
# mean                 NaN              NaN       NaN               NaN
# min                  NaN              NaN       NaN               NaN
# 25%                  NaN              NaN       NaN               NaN
# 50%                  NaN              NaN       NaN               NaN
# 75%                  NaN              NaN       NaN               NaN
# max                  NaN              NaN       NaN               NaN
# std                  NaN              NaN       NaN               NaN
#
#        Manufacturer  Mfg Model  Field Strength  Weighting
# count           0.0        0.0             0.0        0.0
# mean            NaN        NaN             NaN        NaN
# min             NaN        NaN             NaN        NaN
# 25%             NaN        NaN             NaN        NaN
# 50%             NaN        NaN             NaN        NaN
# 75%             NaN        NaN             NaN        NaN
# max             NaN        NaN             NaN        NaN
# std             NaN        NaN             NaN        NaN
# === Categorical Features Summary ===
#        Subject ID Project   Sex Research Group                 Visit  \
# count        7676    7676  7676           7676                  7676
# unique       1793       1     2              2                     1
# top     B56108990      A4     F       amyloidE  SCV4 (Screening MRI)
# freq            9    7676  4554           5342                  7676
#
#        Archive Date Modality  \
# count          7676     7676
# unique           19        1
# top      11/11/2020      MRI
# freq           1446     7676
#
#                                               Description           Type  \
# count                                                7676           7676
# unique                                                150              1
# top     T1; GradWarp; DeFaced <- Sagittal 3D Accelerat...  Pre-processed
# freq                                                 1060           7676
#
#         Image ID Structure Laterality    Image Type Registration Tissue
# count       7676      7676       7676          7676         7676   7676
# unique      7676         1          1             1            1      1
# top      1424280     Brain       Both  image volume       native    All
# freq           1      7676       7676          7676         7676   7676
# === Missing Values by Column ===
#                    Missing Count  Missing %
# Mfg Model                   7676     100.00
# Field Strength              7676     100.00
# Weighting                   7676     100.00
# Acquisition Plane           7676     100.00
# Slice Thickness             7676     100.00
# Matrix Z                    7676     100.00
# Acquisition Type            7676     100.00
# Manufacturer                7676     100.00
# Imaging Protocol            7676     100.00
# Age                          501       6.53
# Weight                       308       4.01
# Description                    0       0.00
# Modality                       0       0.00
# Archive Date                   0       0.00
# Study Date                     0       0.00
# Research Group                 0       0.00
# Visit                          0       0.00
# Project                        0       0.00
# Sex                            0       0.00
# Subject ID                     0       0.00
# Tissue                         0       0.00
# Image Type                     0       0.00
# Registration                   0       0.00
# Structure                      0       0.00
# Image ID                       0       0.00
# Type                           0       0.00
# Laterality                     0       0.00
# Columns with missing values (11):

# %% [markdown]
# # Histograms

# %%
# Separate numeric and categorical columns
numeric_cols = df.select_dtypes(include=np.number).columns
categorical_cols = df.select_dtypes(include=["object", "category"]).columns

# -------------------------------
# Numeric Columns Histograms
# -------------------------------
for col in numeric_cols:
    plt.figure(figsize=(6, 4))

    # Plot histogram
    ax = sns.histplot(
        df[col].dropna(), bins=30, kde=False
    )  # disable KDE for counts clarity

    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")

    # Annotate counts on top of each bin
    for patch in ax.patches:
        height = patch.get_height()
        if height > 0:  # only annotate non-empty bins
            ax.text(
                patch.get_x() + patch.get_width() / 2,  # center of bin
                height + 0.5,  # slightly above the bar
                int(height),  # show integer count
                ha="center",
                va="bottom",
                fontsize=8,
            )

    plt.show()

# -------------------------------
# Categorical Columns Bar Plots
# -------------------------------
categorical_cols = [
    "Visit",
    "Sex",
    "Research Group",
    "Modality",
    "Type",
    "Structure",
    "Laterality",
    "Image Type",
    "Registration",
    "Description",
    "Tissue",
    # Imaging Protocol–derived categorical columns
    "Acquisition Plane",
    "Acquisition Type",
    # "Manufacturer",
    # "Mfg Model",
    "Weighting",
]

categorical_cols = [col for col in categorical_cols if col in df.columns]
for col in categorical_cols:
    plt.figure(figsize=(6, 4))

    counts = df[col].value_counts(dropna=False)
    total = counts.sum()
    order = counts.index

    ax = sns.countplot(y=col, data=df, order=order)

    # Add count + percentage labels
    for p, category in zip(ax.patches, order):
        count = counts[category]
        percent = 100 * count / total

        ax.text(
            p.get_width() + 0.5,
            p.get_y() + p.get_height() / 2,
            f"{count} ({percent:.1f}%)",
            va="center",
        )

    plt.title(f"Value Counts for {col}")
    plt.xlabel("Count")
    plt.ylabel(col)
    plt.tight_layout()
    plt.show()
# Out:
# /tmp/ipykernel_27081/3932520631.py:83: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# # Study dates

# %%
# -------------------------------
# Study Date Distribution
# -------------------------------


plt.figure(figsize=(10, 5))

# Histogram of study dates
ax = sns.histplot(df["Study Date"].dropna(), bins=30, kde=False)

plt.title("Distribution of Study Dates")
plt.xlabel("Study Date")
plt.ylabel("Number of Studies")

# Annotate counts on top of each bin
for patch in ax.patches:
    height = patch.get_height()
    if height > 0:
        ax.text(
            patch.get_x() + patch.get_width() / 2,
            height + 0.5,
            int(height),
            ha="center",
            va="bottom",
            fontsize=8,
        )

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# cumulative study count over time
plt.figure(figsize=(10, 4))
df_sorted = df.sort_values("Study Date")
df_sorted["Cumulative Count"] = range(1, len(df_sorted) + 1)
plt.plot(
    df_sorted["Study Date"], df_sorted["Cumulative Count"], marker="o", linestyle="-"
)
plt.title("Cumulative Study Count Over Time")
plt.xlabel("Study Date")
plt.ylabel("Cumulative Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Scans per session / coverage
#
# Does a subject have more than one scan at a given visit?
#
# How often does this happen?

# %%
df["Visit"] = df["Visit"].astype(str)

# scans per subject per visit
scans_per_subject_visit = (
    df.groupby(["Subject ID", "Visit"], observed=True)
    .size()
    .reset_index(name="n_scans")
)
# Keep only rows with at least 1 scan
scans_per_subject_visit = scans_per_subject_visit[
    scans_per_subject_visit["n_scans"] > 0
].copy()
# print(scans_per_subject_visit.head())
# print(scans_per_subject_visit["n_scans"].min())  # should now be >= 1

# %%
plt.figure(figsize=(6, 4))
ax = sns.countplot(
    x="n_scans",
    data=scans_per_subject_visit,
    order=sorted(scans_per_subject_visit["n_scans"].unique()),
)

plt.xlabel("Number of Scans per Subject per Visit")
plt.ylabel("Number of (Subject, Visit) Sessions")
plt.title("Multiplicity of Scans per Session")

# Annotate counts on top of bars
for p in ax.patches:
    ax.annotate(
        int(p.get_height()),
        (p.get_x() + p.get_width() / 2.0, p.get_height()),
        ha="center",
        va="bottom",
    )

plt.show()

# %% [markdown]
# # Longitudinal analysis - for filtered subset

# %%
df["Visit"].unique()
# Out:
# array(['SCV4 (Screening MRI)'], dtype=object)

# %%
import re
import numpy as np

visit_values = df["Visit"].unique()

scheduled_visits = {}
event_visits = []

for v in visit_values:
    v_clean = str(v).strip()

    if v_clean.lower() == "baseline":
        scheduled_visits[v_clean] = 0
    elif re.match(r"Month\s*(\d+)", v_clean, re.IGNORECASE):
        month_num = int(re.match(r"Month\s*(\d+)", v_clean, re.IGNORECASE).group(1))
        scheduled_visits[v_clean] = month_num
    else:
        event_visits.append(v_clean)

print("Scheduled Visits:", scheduled_visits)
print("Event Visits:", event_visits)
# Out:
# Scheduled Visits: {}
# Event Visits: ['SCV4 (Screening MRI)']

# %%
# Map scheduled visits to months and define visit type
df["Visit_Months"] = df["Visit"].map(scheduled_visits)
df["Visit_Type"] = np.where(
    df["Visit"].isin(scheduled_visits.keys()), "Scheduled", "Event"
)

# Keep only scheduled visits
scheduled_df = df[df["Visit_Type"] == "Scheduled"].copy()

# Count unique scheduled visits per subject
visits_per_subject = (
    scheduled_df.groupby("Subject ID", observed=True)["Visit_Months"]
    .nunique()
    .sort_values(ascending=False)
)

# Summary statistics
summary_stats = visits_per_subject.describe()
print("Longitudinal Coverage per Subject (Scheduled Visits):")
display(summary_stats)

# -------------------------------
# Plot barplot with counts on top
# -------------------------------
# Count how many subjects have each number of visits
visit_counts = visits_per_subject.value_counts().sort_index()

plt.figure(figsize=(6, 4))
ax = sns.barplot(x=visit_counts.index, y=visit_counts.values, palette="Blues_d")

# Annotate each bar with the count
for i, v in enumerate(visit_counts.values):
    ax.text(i, v + 0.5, str(v), ha="center", va="bottom")

plt.xlabel("Number of Scheduled Visits")
plt.ylabel("Number of Subjects")
plt.title("Longitudinal Follow-up Depth (Scheduled Visits Only)")
plt.xticks(range(len(visit_counts.index)), visit_counts.index)
plt.ylim(0, visit_counts.values.max() * 1.1)  # Add some space for annotations
plt.show()
# Out:
# Longitudinal Coverage per Subject (Scheduled Visits):
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Visit_Months, dtype: float64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[182], line 39
#      37 plt.title("Longitudinal Follow-up Depth (Scheduled Visits Only)")
#      38 plt.xticks(range(len(visit_counts.index)), visit_counts.index)
# ---> 39 plt.ylim(0, visit_counts.values.max() * 1.1)  # Add some space for annotations
#      40 plt.show()
#
# File ~/Documents/mri-preprocessing/.venv/lib/python3.12/site-packages/numpy/_core/_methods.py:41, in _amax(a, axis, out, keepdims, initial, where)
#      39 def _amax(a, axis=None, out=None, keepdims=False,
#      40           initial=_NoValue, where=True):
# ---> 41     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
# Compute retention
# the number of unique subjects (Subject ID) present at each scheduled visit month (Visit_Months)
retention = (
    scheduled_df.groupby("Visit_Months", observed=True)["Subject ID"]
    .nunique()
    .sort_index()
)

# -----------------------------
# Line plot with exact numbers
# -----------------------------
plt.figure(figsize=(7, 4))
plt.plot(retention.index, retention.values, marker="o", linewidth=2)

# Annotate each point with the exact number
for x, y in zip(retention.index, retention.values):
    plt.text(x, y + 0.5, str(y), ha="center", va="bottom", fontsize=10)

plt.xlabel("Months from Baseline")
plt.ylabel("Number of Active Subjects")
plt.title("Subject Retention Over Time")
plt.grid(True)
plt.ylim(0, retention.values.max() * 1.1)
plt.show()

# -----------------------------
# Bar plot with exact numbers
# -----------------------------
plt.figure(figsize=(8, 4))
ax = sns.barplot(x=retention.index, y=retention.values, palette="Blues_d")

# Annotate each bar with the exact number
for i, v in enumerate(retention.values):
    ax.text(i, v + 0.5, str(v), ha="center", va="bottom", fontsize=10)

plt.xlabel("Visit Month")
plt.ylabel("Number of Subjects")
plt.title("Number of Subjects per Scheduled Visit")
plt.ylim(0, retention.values.max() * 1.1)
plt.show()
# Out:
# /tmp/ipykernel_23190/2829091273.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=retention.index, y=retention.values, palette="Blues_d")

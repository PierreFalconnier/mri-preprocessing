# %%
from pathlib import Path

import pandas as pd

# %%
# dirpath = Path(__file__).parent.resolve()
dirpath = Path.cwd()
qc_csv_outlier_dir = dirpath / "qc_results"
qc_csv_files = list(qc_csv_outlier_dir.glob("*.csv"))

# %%
qc_csv_file = qc_csv_files[0]
print(qc_csv_file)
outliers = pd.read_csv(qc_csv_file)

print(outliers.describe().T)
print(list(outliers.columns))
print(outliers["path"].nunique())
# plot_histogram(outliers, "dim_x")
# Out:
# /home/falconnier/Documents/mri-preprocessing/quality_control/qc_results/NPC_t1w_qc_metrics_20260130_155934.csv
#               count          mean           std           min           25%  \
# error           0.0           NaN           NaN           NaN           NaN
# tesla           0.0           NaN           NaN           NaN           NaN
# manufacturer    0.0           NaN           NaN           NaN           NaN
# model           0.0           NaN           NaN           NaN           NaN
# session         0.0           NaN           NaN           NaN           NaN
# dim_x          66.0  3.200000e+02  0.000000e+00  3.200000e+02  3.200000e+02
# dim_y          66.0  3.200000e+02  0.000000e+00  3.200000e+02  3.200000e+02
# dim_z          66.0  2.560000e+02  0.000000e+00  2.560000e+02  2.560000e+02
# voxel_x_mm     66.0  7.000000e-01  2.237461e-16  7.000000e-01  7.000000e-01
# voxel_y_mm     66.0  7.000000e-01  2.237461e-16  7.000000e-01  7.000000e-01
# voxel_z_mm     66.0  7.000000e-01  2.237461e-16  7.000000e-01  7.000000e-01
# file_size_mb   66.0  2.942090e+01  9.530700e-01  2.740106e+01  2.881675e+01
# n_voxels       66.0  2.621440e+07  0.000000e+00  2.621440e+07  2.621440e+07
# n_nonzero      66.0  2.230512e+07  5.908972e+04  2.212807e+07  2.226995e+07
# nonzero_frac   66.0  8.508728e-01  2.254094e-03  8.441190e-01  8.495312e-01
# min            66.0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max            66.0  1.496121e+03  3.854337e+02  1.024000e+03  1.249000e+03
# mean           66.0  1.404086e+02  2.371179e+01  9.911476e+01  1.222784e+02
# median         66.0  5.080303e+01  3.407242e+01  1.800000e+01  2.625000e+01
# std            66.0  1.669849e+02  2.318095e+01  1.234703e+02  1.490253e+02
# mad            66.0  4.868182e+01  3.312130e+01  1.600000e+01  2.425000e+01
# kurtosis       66.0  1.618638e+00  7.950409e-01 -1.116395e-01  1.228787e+00
# skewness       66.0  1.290115e+00  1.989547e-01  7.267516e-01  1.178214e+00
# p01            66.0  1.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# p05            66.0  1.954545e+00  2.098951e-01  1.000000e+00  2.000000e+00
# p95            66.0  4.521212e+02  7.733832e+01  3.240000e+02  3.960000e+02
# p99            66.0  6.800758e+02  1.008001e+02  4.910000e+02  6.062500e+02
# entropy        66.0  1.382109e+00  2.584814e-01  6.963156e-01  1.242501e+00
# efc            66.0  5.688091e-01  2.527472e-02  5.228000e-01  5.478000e-01
#
#                        50%           75%           max
# error                  NaN           NaN           NaN
# tesla                  NaN           NaN           NaN
# manufacturer           NaN           NaN           NaN
# model                  NaN           NaN           NaN
# session                NaN           NaN           NaN
# dim_x         3.200000e+02  3.200000e+02  3.200000e+02
# dim_y         3.200000e+02  3.200000e+02  3.200000e+02
# dim_z         2.560000e+02  2.560000e+02  2.560000e+02
# voxel_x_mm    7.000000e-01  7.000000e-01  7.000000e-01
# voxel_y_mm    7.000000e-01  7.000000e-01  7.000000e-01
# voxel_z_mm    7.000000e-01  7.000000e-01  7.000000e-01
# file_size_mb  2.929214e+01  2.988350e+01  3.229662e+01
# n_voxels      2.621440e+07  2.621440e+07  2.621440e+07
# n_nonzero     2.231372e+07  2.234756e+07  2.239875e+07
# nonzero_frac  8.512010e-01  8.524919e-01  8.544446e-01
# min           0.000000e+00  0.000000e+00  0.000000e+00
# max           1.374500e+03  1.579750e+03  2.894000e+03
# mean          1.378769e+02  1.561343e+02  2.206739e+02
# median        3.750000e+01  6.875000e+01  1.880000e+02
# std           1.641453e+02  1.809447e+02  2.353270e+02
# mad           3.650000e+01  6.675000e+01  1.780000e+02
# kurtosis      1.496600e+00  2.053436e+00  4.775215e+00
# skewness      1.280560e+00  1.449060e+00  1.726791e+00
# p01           1.000000e+00  1.000000e+00  1.000000e+00
# p05           2.000000e+00  2.000000e+00  2.000000e+00
# p95           4.420000e+02  4.900000e+02  7.000000e+02
# p99           6.755000e+02  7.307500e+02  9.580000e+02
# entropy       1.406394e+00  1.562659e+00  1.870243e+00
# efc           5.675500e-01  5.899000e-01  6.297000e-01
# ['dataset', 'path', 'error', 'tesla', 'manufacturer', 'model', 'subject', 'session', 'dim_x', 'dim_y', 'dim_z', 'voxel_x_mm', 'voxel_y_mm', 'voxel_z_mm', 'file_size_mb', 'n_voxels', 'n_nonzero', 'nonzero_frac', 'min', 'max', 'mean', 'median', 'std', 'mad', 'kurtosis', 'skewness', 'p01', 'p05', 'p95', 'p99', 'entropy', 'efc']
# 66
